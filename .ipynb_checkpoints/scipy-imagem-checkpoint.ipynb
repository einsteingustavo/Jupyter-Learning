# %% [markdown]
# # SciPy - Processamento de Imagens

# %% [markdown]
# Scipy tem uma biblioteca com várias funções para processamento de imagens, incluindo funções para filtragens linear e não-linear, morfologia binária, interpolação e medição de objetos.

# %% [markdown]
# Podemos trabalhar facilmente com imagens em SciPy, tanto imagens coloridas como em tons de cinza.  As imagens são armazenadas em ndarrays.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import scipy.ndimage as ndi
from pathlib import Path
import imageio.v2 as ndio

# %%
im1 = ndio.imread("girl.jpg")
im2 = ndio.imread("high_contrast.jpg")
plt.subplot(121)
fig = plt.imshow(im1)
fig.axes.set_axis_off()
plt.subplot(122)
fig = plt.imshow(im2, cmap="gray")
fig.axes.set_axis_off()

# %%
print("Dimensões da 1a imagem:", im1.shape)
print("Dimensões da 2a imagem:", im2.shape)
# Out:
# Dimensões da 1a imagem: (665, 1000, 3)
# Dimensões da 2a imagem: (665, 998)

# %% [markdown]
# A imagem colorida é armazenada em ndarray com 3 dimensões, sendo a terceira de comprimento 3 ou 4, contendo cada subarray os valores para o vermelho, verde, azul e, opcionalmente, o canal de transparência.  Estas subarrays podem ser acessadas individualmente

# %%
im = ndio.imread("girl.jpg")
plt.subplot(221)
fig = plt.imshow(im)
fig.axes.set_axis_off()
plt.subplot(222)
fig = plt.imshow(im[:, :, 0], cmap="Reds")
fig.axes.set_axis_off()
plt.subplot(223)
fig = plt.imshow(im[:, :, 1], cmap="Greens")
fig.axes.set_axis_off()
plt.subplot(224)
fig = plt.imshow(im[:, :, 2], cmap="Blues")
fig.axes.set_axis_off()

# %%
im2 = im.copy()
im2[im2 > 150] *= 1.2
im2 = im2.astype(np.uint8)
im2[im2 > 255] = 255
plt.imshow(im2)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 im2 = im.copy()
# ----> 2 im2[im2 > 150] *= 1.2
#       3 im2 = im2.astype(np.uint8)
#       4 im2[im2 > 255] = 255
#
# UFuncTypeError: Cannot cast ufunc 'multiply' output from dtype('float64') to dtype('uint8') with casting rule 'same_kind'

# %% [markdown]
# Uma imagem colorida pode ser lida automaticamente em tons de cinza através do parâmetro `flatten` da função `imread`.

# %%
im1 = ndio.imread("girl.jpg")
im2 = ndio.imread("girl.jpg", flatten=True)
plt.subplot(121)
fig = plt.imshow(im1)
fig.axes.set_axis_off()
plt.subplot(122)
fig = plt.imshow(im2, cmap="gray")
fig.axes.set_axis_off()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       1 im1 = ndio.imread("girl.jpg")
# ----> 2 im2 = ndio.imread("girl.jpg", flatten=True)
#       3 plt.subplot(121)
#       4 fig = plt.imshow(im1)
#
# File ~/.local/lib/python3.8/site-packages/imageio/v2.py:201, in imread(uri, format, **kwargs)
#     198 imopen_args["legacy_mode"] = True
#     200 with imopen(uri, "ri", **imopen_args) as file:
# --> 201     return file.read(index=0, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/imageio/core/legacy_plugin_wrapper.py:147, in LegacyPlugin.read(self, index, **kwargs)
#     144     img = np.stack([im for im in self.iter(**kwargs)])
#     145     return img
# --> 147 reader = self.legacy_get_reader(**kwargs)
#     148 return reader.get_data(index)
#
# File ~/.local/lib/python3.8/site-packages/imageio/core/legacy_plugin_wrapper.py:116, in LegacyPlugin.legacy_get_reader(self, **kwargs)
#     113     return self._format.get_reader(self._request)
#     115 self._request.get_file().seek(0)
# --> 116 return self._format.get_reader(self._request)
#
# File ~/.local/lib/python3.8/site-packages/imageio/core/format.py:220, in Format.get_reader(self, request)
#     216 if select_mode not in self.modes:
#     217     raise RuntimeError(
#     218         f"Format {self.name} cannot read in {request.mode.image_mode} mode"
#     219     )
# --> 220 return self.Reader(self, request)
#
# File ~/.local/lib/python3.8/site-packages/imageio/core/format.py:311, in Format._BaseReaderWriter.__init__(self, format, request)
#     309 self._request = request
#     310 # Open the reader/writer
# --> 311 self._open(**self.request.kwargs.copy())
#
# TypeError: _open() got an unexpected keyword argument 'flatten'

# %% [markdown]
# Toda imagem tem os valores de seus pixels distribuídos por uma faixa de valores.  Podemos construir um histograma desses valores para termos uma ideia de como a imagem parece.

# %%
plt.subplot(211)
fig = plt.imshow(im2, cmap="gray")
fig.axes.set_axis_off()
plt.subplot(212)
_ = plt.plot(np.arange(256)/256, ndi.histogram(im2, min=0, max=255, bins=256))

# %%
im3 = im2.copy()
im3[im2[:,:] < 90] = 90
im3[im2[:,:] > 160] = 160
plt.subplot(211)
fig = plt.imshow(im3, cmap="gray")
fig.axes.set_axis_off()
plt.subplot(212)
l = 159-91+1
_ = plt.plot((91 + np.arange(l))/256, ndi.histogram(im3, min=91, max=159, bins=l))
